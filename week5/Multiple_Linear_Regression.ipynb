# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df_og = pd.read_csv("funda-amsterdam.csv")
df = df_og[df_og["price"] > 10000]

# %%
df
# Out:
#        Unnamed: 0                                address  area  bedrooms  \
# 0               0              Knollendamstraat 4 III/IV   108         2
# 1               1                    Moerdijkstraat 47 1    47         1
# 2               2                      Zeeburgerdijk 349   116         2
# 3               3                 Brederodestraat 124 -1    58         2
# 4               4         Admiraal De Ruijterweg 409 III    63         1
# 5               5              Bertrand Russellstraat 46   125         2
# 6               6           Admiraal De Ruijterweg 417 I    64         3
# 7               7                  Deltastraat 10 -boven   155         3
# 8               8            Ben van Meerendonkstraat 49    85         2
# 9               9           Jacob van Lennepstraat 263 B    67         2
# 10             10                   Spaarndammerdijk 581   100         3
# 11             11          Van Reigersbergenstraat 47 II    43         1
# ...

# %%
df2 = df[["price","area","rooms","year_built"]]

# %%
y = df2['price'] # price = y variable
X = df2.loc[:,'area':'year_built']
X.head()
# Out:
#    area  rooms  year_built
# 0   108      3        1906
# 1    47      2        1938
# 2   116      3        2003
# 3    58      3        1910
# 4    63      3        1906

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) #split the data, store it into different variables

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
coef = pd.DataFrame(X.columns.values, lm.coef_)
coef
# Out:
#                         0
#  4251.295299         area
# -16530.404794       rooms
# -1141.852158   year_built

# %%
y_p = lm.predict(X_test) #Generate predictions for the test data. So we use X.test, not X.train
r2_score(y_test, y_p)
# Out:
# 0.6521403798622318

# %%
# saying what the mean squared error is, how much we are off on average, as low as possible.
math.sqrt(mean_squared_error(y_test, y_p))
# Out:
# 101573.38487700601

# %%
sns.scatterplot(y_test, y_p)
plt.xlabel('Actual rating')
plt.ylabel('Predicted rating')
plt.show()
